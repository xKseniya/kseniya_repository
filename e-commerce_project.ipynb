# %%
import numpy as np
import pandas as pd
import scipy.stats as ss

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(12,6)}, style="whitegrid")

# %% [markdown]
# ## Проект e-commerce
#
# Продакт-менеджер Василий попросил вас проанализировать совершенные покупки и ответить на следующие вопросы:
#
# 1. Сколько у нас пользователей, которые совершили покупку только один раз?
#
# 2. Сколько заказов в месяц в среднем не доставляется по разным причинам (вывести детализацию по причинам)?
#
# 3. По каждому товару определить, в какой день недели товар чаще всего покупается.
#
# 4. Сколько у каждого из пользователей в среднем покупок в неделю (по месяцам)? Не стоит забывать, что внутри месяца может быть не целое количество недель. Например, в ноябре 2021 года 4,28 недели. И внутри метрики это нужно учесть.
#
# 5. Напиши функцию на python, позволяющую строить когортный анализ. В период с января по декабрь выяви когорту с самым высоким retention на 3-й месяц.
#
# 6. Построй RFM-кластеры для пользователей. Выведи для каждого кластера средние значения метрик R, F, M (и опиши подробно, как были построены метрики R, F, M).

# %% [markdown]
# ##### Файлы:
#
# ##### olist_customers_datase.csv — таблица с уникальными идентификаторами пользователей
# - customer_id — позаказный идентификатор пользователя (аналог номера паспорта)
# - customer_unique_id —  уникальный идентификатор пользователя
# - customer_zip_code_prefix —  почтовый индекс пользователя
# - customer_city —  город доставки пользователя
# - customer_state —  штат доставки пользователя
#
# #### olist_orders_dataset.csv —  таблица заказов
# - order_id —  уникальный идентификатор заказа (номер чека)
# - customer_id —  позаказный идентификатор пользователя (аналог номера паспорта)
# - order_status —  статус заказа
# - order_purchase_timestamp —  время создания заказа
# - order_approved_at —  время подтверждения оплаты заказа
# - order_delivered_carrier_date —  время передачи заказа в логистическую службу
# - order_delivered_customer_date —  время доставки заказа
# - order_estimated_delivery_date —  обещанная дата доставки
#
# #### olist_order_items_dataset.csv —  товарные позиции, входящие в заказы
# - order_id —  уникальный идентификатор заказа (номер чека)
# - order_item_id —  идентификатор товара внутри одного заказа
# - product_id —  ид товара (аналог штрихкода)
# - seller_id — ид производителя товара
# - shipping_limit_date —  максимальная дата доставки продавцом для передачи заказа партнеру по логистике
# - price —  цена за единицу товара
# - freight_value —  вес товара

# %% [markdown]
# ###### Уникальные статусы заказов в таблице olist_order_items_dataset:
#
# - created —  создан
# - approved —  подтверждён
# - invoiced —  выставлен счёт
# - processing —  в процессе сборки заказа
# - shipped —  отгружен со склада
# - delivered —  доставлен пользователю
# - unavailable —  недоступен
# - canceled —  отменён

# %%
customers = pd.read_csv('olist_customers_dataset.csv')
orders = pd.read_csv('olist_orders_dataset.csv')
items = pd.read_csv('olist_order_items_dataset.csv')

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
# перевожу столбцы с датами в формат datetime
orders[['order_purchase_timestamp', 
        'order_approved_at', 
        'order_delivered_carrier_date', 
        'order_delivered_customer_date', 
        'order_estimated_delivery_date']] = orders[['order_purchase_timestamp', 
                                                    'order_approved_at', 
                                                    'order_delivered_carrier_date', 
                                                    'order_delivered_customer_date', 
                                                    'order_estimated_delivery_date']].astype('datetime64')

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %% [markdown]
# #### Сколько у нас пользователей, которые совершили покупку только один раз?

# %%
# мерджу уникальные ид клиентов с ид и статусами заказов
df_1 = customers[['customer_id', 'customer_unique_id']]\
                .merge(orders[['order_id', 'customer_id', 'order_status']], on='customer_id')

# %%
df_1.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#                            order_id order_status
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered
# 1  29150127e6685892b6eab3eec79f59c7    delivered
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered
# 3  951670f92359f4fe4a63112aa7306eba    delivered
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered

# %%
# считаю пользователей, которые совершили покупку только один раз (покупка совершена при статусе "delivered")

df_1[df_1.order_status == 'delivered'].groupby('customer_unique_id')\
                                      .agg({'order_id' : 'count'})\
                                      .query('order_id == 1')\
                                      .count()
# Out:
# order_id    90557
# dtype: int64

# %% [markdown]
# ##### 90557 пользователей совершили покупку только один раз

# %% [markdown]
# #### Сколько заказов в месяц в среднем не доставляется по разным причинам (вывести детализацию по причинам)?

# %% [markdown]
# Смотрим на заказы со статусами unavailable и canceled

# %%
orders['month'] = orders.order_purchase_timestamp.dt.strftime('%Y-%m')

# %%
# Детализация по месяцам и причинам

pd.crosstab(orders.query('order_status == "canceled" or order_status == "unavailable"').month, 
            orders.query('order_status == "canceled" or order_status == "unavailable"').order_status)
# Out:
# order_status  canceled  unavailable
# month
# 2016-09              2            0
# 2016-10             24            7
# 2017-01              3           10
# 2017-02             17           45
# 2017-03             33           32
# 2017-04             18            9
# 2017-05             29           31
# 2017-06             16           24
# 2017-07             28           52
# 2017-08             27           32
# 2017-09             20           38
# 2017-10             26           58
# 2017-11             37           84
# 2017-12             11           42
# 2018-01             34           48
# 2018-02             73           30
# 2018-03             26           17
# 2018-04             15            5
# 2018-05             24           16
# 2018-06             18            4
# 2018-07             41           18
# 2018-08             84            7
# 2018-09             15            0
# 2018-10              4            0

# %%
# В среднем не доставлено в месяц

pd.crosstab(orders.query('order_status == "canceled" or order_status == "unavailable"').month, 
            orders.query('order_status == "canceled" or order_status == "unavailable"').order_status)\
            .mean().round(2)
# Out:
# order_status
# canceled       26.04
# unavailable    25.38
# dtype: float64

# %% [markdown]
# ##### По каждому товару определить, в какой день недели товар чаще всего покупается.

# %%
orders['day_of_week'] = orders.order_purchase_timestamp.dt.day_name()

# %%
df_2 = items[['order_id', 'product_id']].merge(orders[['order_id', 'day_of_week']], on='order_id')

# %%
# вывожу id товара и день недели, в который его чаще покупали

df_2.groupby(['product_id', 'day_of_week'], as_index=False)\
    .agg({'order_id' : 'count'})\
    .sort_values('order_id', ascending=False)\
    .drop_duplicates(subset=['product_id'])\
    .reset_index(drop=True)\
    [['product_id', 'day_of_week']]
# Out:
#                              product_id day_of_week
# 0      422879e10f46682990de24d770e7f83d   Wednesday
# 1      99a4788cb24856965c36a24e339b6058      Monday
# 2      aca2eb7d00ea1a7b8ebd4e68314663af    Thursday
# 3      53b36df67ebb7c41585e8d54d6772e08     Tuesday
# 4      389d119b48cf3043d311335e499d9c6b    Thursday
# ...                                 ...         ...
# 32946  6432d844f2be41bb6f2fd279e23415da      Friday
# 32947  6421ae053bb80dff3ceae1f217f54ed4      Monday
# 32948  642247ccf62585635cefa1bf09f59b94      Sunday
# 32949  642e125cbc752b4eeb8faf442319c39f    Thursday
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58   Wednesday
#
# [32951 rows x 2 columns]

# %%
items.product_id.nunique()
# Out:
# 32951

# %% [markdown]
# #### Сколько у каждого из пользователей в среднем покупок в неделю (по месяцам)? Не стоит забывать, что внутри месяца может быть не целое количество недель. Например, в ноябре 2021 года 4,28 недели. И внутри метрики это нужно учесть.

# %%
# Добавляю столбец с количеством недель в текущем месяце
orders['weeks_in_month'] = round(orders.order_purchase_timestamp.dt.daysinmonth/7, 2)

# %%
df_3 = customers[['customer_id', 'customer_unique_id']]\
                .merge(orders[['order_id', 'customer_id', 'month', 'weeks_in_month']], on='customer_id')

# %%
df_3 = df_3.groupby(['customer_unique_id','month', 'weeks_in_month'], as_index=False)\
           .agg({'order_id' : 'count'})\
           .rename(columns={'order_id' : 'total_in_month'})\
           .reset_index(drop=True)

# %%
df_3 ['mean_for_week'] = df_3.total_in_month / df_3.weeks_in_month

# %%
# среднее количество покупок для каждого пользователя в неделю (по месяцам)
df_3[['customer_unique_id','month', 'mean_for_week']]
# Out:
#                      customer_unique_id  month  mean_for_week
# 0      0000366f3b9a7992bf8c76cfdf3221e2      5       0.225734
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      5       0.225734
# 2      0000f46a3911fa3c0805444483337064      3       0.225734
# 3      0000f6ccb0745a6a4b88665a16c9f078     10       0.225734
# 4      0004aac84e0df4da2b147fca70cf8255     11       0.233100
# ...                                 ...    ...            ...
# 97996  fffcf5a5ff07b0908bd4e2dbc735a684      6       0.233100
# 97997  fffea47cd6d3cc0a88bd621562a9d061     12       0.225734
# 97998  ffff371b4d645b6ecea244b27531430a      2       0.250000
# 97999  ffff5962728ec6157033ef9805bacc48      5       0.225734
# 98000  ffffd2657e2aad2907e67c3e9daecbeb      5       0.225734
#
# [98001 rows x 3 columns]

# %% [markdown]
# #### Напиши функцию на python, позволяющую строить когортный анализ. В период с января по декабрь выяви когорту с самым высоким retention на 3-й месяц.

# %%
# Собираю датафрейм, с которым буду работать
df_4 = orders[['order_purchase_timestamp' , 'customer_id', 'order_id']].merge(customers[['customer_id', 'customer_unique_id']])
df_4.head()
# Out:
#   order_purchase_timestamp                       customer_id  \
# 0      2017-10-02 10:56:33  9ef432eb6251297304e76186b10a928d
# 1      2018-07-24 20:41:37  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2018-08-08 08:38:49  41ce2a54c0b03bf3443c3d931a367089
# 3      2017-11-18 19:28:06  f88197465ea7920adcdbec7375364d82
# 4      2018-02-13 21:18:39  8ab97904e6daea8866dbdbc4fb7aad2c
#
#                            order_id                customer_unique_id
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6

# %%
# Функция для разбиения на когорты по месяцам
def cohort_by_month(df):
    df = df.groupby('customer_unique_id', as_index=False).agg({'order_purchase_timestamp' : 'min'})
    df['Cohort'] = df['order_purchase_timestamp'].dt.strftime('%Y-%m')
        
    return df[['customer_unique_id', 'Cohort']]

# %%
cohorts = cohort_by_month(df_4)
cohorts.head()
# Out:
#                  customer_unique_id   Cohort
# 0  0000366f3b9a7992bf8c76cfdf3221e2  2018-05
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  2018-05
# 2  0000f46a3911fa3c0805444483337064  2017-03
# 3  0000f6ccb0745a6a4b88665a16c9f078  2017-10
# 4  0004aac84e0df4da2b147fca70cf8255  2017-11

# %%
df_4 = df_4.merge(cohorts)
df_4['order_purchase_timestamp'] = df_4['order_purchase_timestamp'].dt.strftime('%Y-%m')
df_4.rename(columns={'order_purchase_timestamp': 'order_period'}, inplace=True)
df_4.head()
# Out:
#   order_period                       customer_id  \
# 0      2017-10  9ef432eb6251297304e76186b10a928d
# 1      2017-09  31f31efcb333fcbad2b1371c8cf0fa84
# 2      2018-07  b0830fb4747a6c6d20dea0b8c802d7ef
# 3      2018-08  41ce2a54c0b03bf3443c3d931a367089
# 4      2017-11  f88197465ea7920adcdbec7375364d82
#
#                            order_id                customer_unique_id   Cohort
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff  2017-09
# 1  69923a4e07ce446644394df37a710286  7c396fd4830fd04220f754e42b4e5bff  2017-09
# 2  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231  2018-07
# 3  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8  2018-08
# 4  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977  2017-11

# %%
# Функция для создания периодов для когорт
def cohort_period(df):
    df['cohort_period'] = np.arange(len(df))
    return df

# %%
# Функция для построения когортного анализа

def retention_by_cohort(df):
    # считаем уникальных пользователей и число заказов по когортам и периодам заказов
    cohorts = df.groupby(['Cohort', 'order_period']).agg({'customer_unique_id': 'nunique',
                                                           'order_id': 'nunique'})
    # переименовываем колонки
    cohorts.rename(columns={'customer_unique_id': 'total_users',
                            'order_id': 'total_orders'}, inplace=True)  

    cohorts = cohorts.groupby(level=0).apply(cohort_period)
    
    # реиндексируем датафрейм
    cohorts.reset_index(inplace=True)
    cohorts.set_index(['Cohort', 'cohort_period'], inplace=True)

    # создаем серию, в которую помещаем размер когорт
    cohort_group_size = cohorts['total_users'].groupby(level=0).first()
    cohort_group_size.head()

    # считаем retention
    user_retention = cohorts['total_users'].unstack(1).divide(cohort_group_size, axis=0)

    return user_retention

# %%
user_retention = retention_by_cohort(df_4)

# %%
# добавим стиля
ur_style = (user_retention
            .style
            .set_caption('User retention by cohort')  # добавляем подпись
            .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style  type="text/css" >
# #T_479c1_row0_col0,#T_479c1_row1_col0,#T_479c1_row1_col1,#T_479c1_row2_col0,#T_479c1_row3_col0,#T_479c1_row3_col1,#T_479c1_row3_col17,#T_479c1_row4_col0,#T_479c1_row4_col1,#T_479c1_row4_col5,#T_479c1_row4_col10,#T_479c1_row4_col15,#T_479c1_row4_col16,#T_479c1_row5_col0,#T_479c1_row5_col1,#T_479c1_row6_col0,#T_479c1_row6_col12,#T_479c1_row6_col14,#T_479c1_row7_col0,#T_479c1_row7_col1,#T_479c1_row7_col13,#T_479c1_row8_col0,#T_479c1_row8_col1,#T_479c1_row8_col8,#T_479c1_row9_col0,#T_479c1_row10_col0,#T_479c1_row11_col0,#T_479c1_row11_col11,#T_479c1_row12_col0,#T_479c1_row13_col0,#T_479c1_row13_col6,#T_479c1_row13_col9,#T_479c1_row14_col0,#T_479c1_row14_col1,#T_479c1_row14_col7,#T_479c1_row15_col0,#T_479c1_row15_col1,#T_479c1_row16_col0,#T_479c1_row16_col1,#T_479c1_row17_col0,#T_479c1_row17_col1,#T_479c1_row17_col4,#T_479c1_row18_col0,#T_479c1_row19_col0,#T_479c1_row20_col0,#T_479c1_row20_col1,#T_479c1_row20_col3,#T_479c1_row21_col0,#T_479c1_row21_col2,#T_479c1_row22_col0,#T_479c1_row22_col1,#T_479c1_row22_col2,#T_479c1_row23_col0,#T_479c1_row24_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_479c1_row0_col1,#T_479c1_row0_col2,#T_479c1_row0_col3,#T_479c1_row0_col4,#T_479c1_row0_col5,#T_479c1_row0_col6,#T_479c1_row0_col7,#T_479c1_row0_col8,#T_479c1_row0_col9,#T_479c1_row0_col10,#T_479c1_row0_col11,#T_479c1_row0_col12,#T_479c1_row0_col13,#T_479c1_row0_col14,#T_479c1_row0_col15,#T_479c1_row0_col16,#T_479c1_row0_col17,#T_479c1_row1_col9,#T_479c1_row1_col10,#T_479c1_row1_col11,#T_479c1_row1_col12,#T_479c1_row1_col13,#T_479c1_row1_col14,#T_479c1_row1_col15,#T_479c1_row1_col16,#T_479c1_row1_col17,#T_479c1_row2_col2,#T_479c1_row2_col3,#T_479c1_row2_col4,#T_479c1_row2_col5,#T_479c1_row2_col6,#T_479c1_row2_col7,#T_479c1_row2_col8,#T_479c1_row2_col9,#T_479c1_row2_col10,#T_479c1_row2_col11,#T_479c1_row2_col12,#T_479c1_row2_col13,#T_479c1_row2_col14,#T_479c1_row2_col15,#T_479c1_row2_col16,#T_479c1_row2_col17,#T_479c1_row6_col17,#T_479c1_row7_col16,#T_479c1_row7_col17,#T_479c1_row8_col15,#T_479c1_row8_col16,#T_479c1_row8_col17,#T_479c1_row9_col14,#T_479c1_row9_col15,#T_479c1_row9_col16,#T_479c1_row9_col17,#T_479c1_row10_col13,#T_479c1_row10_col14,#T_479c1_row10_col15,#T_479c1_row10_col16,#T_479c1_row10_col17,#T_479c1_row11_col12,#T_479c1_row11_col13,#T_479c1_row11_col14,#T_479c1_row11_col15,#T_479c1_row11_col16,#T_479c1_row11_col17,#T_479c1_row12_col11,#T_479c1_row12_col12,#T_479c1_row12_col13,#T_479c1_row12_col14,#T_479c1_row12_col15,#T_479c1_row12_col16,#T_479c1_row12_col17,#T_479c1_row13_col10,#T_479c1_row13_col11,#T_479c1_row13_col12,#T_479c1_row13_col13,#T_479c1_row13_col14,#T_479c1_row13_col15,#T_479c1_row13_col16,#T_479c1_row13_col17,#T_479c1_row14_col9,#T_479c1_row14_col10,#T_479c1_row14_col11,#T_479c1_row14_col12,#T_479c1_row14_col13,#T_479c1_row14_col14,#T_479c1_row14_col15,#T_479c1_row14_col16,#T_479c1_row14_col17,#T_479c1_row15_col8,#T_479c1_row15_col9,#T_479c1_row15_col10,#T_479c1_row15_col11,#T_479c1_row15_col12,#T_479c1_row15_col13,#T_479c1_row15_col14,#T_479c1_row15_col15,#T_479c1_row15_col16,#T_479c1_row15_col17,#T_479c1_row16_col7,#T_479c1_row16_col8,#T_479c1_row16_col9,#T_479c1_row16_col10,#T_479c1_row16_col11,#T_479c1_row16_col12,#T_479c1_row16_col13,#T_479c1_row16_col14,#T_479c1_row16_col15,#T_479c1_row16_col16,#T_479c1_row16_col17,#T_479c1_row17_col6,#T_479c1_row17_col7,#T_479c1_row17_col8,#T_479c1_row17_col9,#T_479c1_row17_col10,#T_479c1_row17_col11,#T_479c1_row17_col12,#T_479c1_row17_col13,#T_479c1_row17_col14,#T_479c1_row17_col15,#T_479c1_row17_col16,#T_479c1_row17_col17,#T_479c1_row18_col5,#T_479c1_row18_col6,#T_479c1_row18_col7,#T_479c1_row18_col8,#T_479c1_row18_col9,#T_479c1_row18_col10,#T_479c1_row18_col11,#T_479c1_row18_col12,#T_479c1_row18_col13,#T_479c1_row18_col14,#T_479c1_row18_col15,#T_479c1_row18_col16,#T_479c1_row18_col17,#T_479c1_row19_col4,#T_479c1_row19_col5,#T_479c1_row19_col6,#T_479c1_row19_col7,#T_479c1_row19_col8,#T_479c1_row19_col9,#T_479c1_row19_col10,#T_479c1_row19_col11,#T_479c1_row19_col12,#T_479c1_row19_col13,#T_479c1_row19_col14,#T_479c1_row19_col15,#T_479c1_row19_col16,#T_479c1_row19_col17,#T_479c1_row20_col4,#T_479c1_row20_col5,#T_479c1_row20_col6,#T_479c1_row20_col7,#T_479c1_row20_col8,#T_479c1_row20_col9,#T_479c1_row20_col10,#T_479c1_row20_col11,#T_479c1_row20_col12,#T_479c1_row20_col13,#T_479c1_row20_col14,#T_479c1_row20_col15,#T_479c1_row20_col16,#T_479c1_row20_col17,#T_479c1_row21_col3,#T_479c1_row21_col4,#T_479c1_row21_col5,#T_479c1_row21_col6,#T_479c1_row21_col7,#T_479c1_row21_col8,#T_479c1_row21_col9,#T_479c1_row21_col10,#T_479c1_row21_col11,#T_479c1_row21_col12,#T_479c1_row21_col13,#T_479c1_row21_col14,#T_479c1_row21_col15,#T_479c1_row21_col16,#T_479c1_row21_col17,#T_479c1_row22_col3,#T_479c1_row22_col4,#T_479c1_row22_col5,#T_479c1_row22_col6,#T_479c1_row22_col7,#T_479c1_row22_col8,#T_479c1_row22_col9,#T_479c1_row22_col10,#T_479c1_row22_col11,#T_479c1_row22_col12,#T_479c1_row22_col13,#T_479c1_row22_col14,#T_479c1_row22_col15,#T_479c1_row22_col16,#T_479c1_row22_col17,#T_479c1_row23_col1,#T_479c1_row23_col2,#T_479c1_row23_col3,#T_479c1_row23_col4,#T_479c1_ro ...
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_479c1_row1_col2,#T_479c1_row6_col6,#T_479c1_row18_col3{
#             background-color:  #1f9e89;
#             color:  #000000;
#         }#T_479c1_row1_col3{
#             background-color:  #58c765;
#             color:  #000000;
#         }#T_479c1_row1_col4{
#             background-color:  #1e9d89;
#             color:  #000000;
#         }#T_479c1_row1_col5,#T_479c1_row9_col6,#T_479c1_row19_col2{
#             background-color:  #228b8d;
#             color:  #000000;
#         }#T_479c1_row1_col6{
#             background-color:  #228d8d;
#             color:  #000000;
#         }#T_479c1_row1_col7,#T_479c1_row1_col8,#T_479c1_row2_col1,#T_479c1_row3_col6,#T_479c1_row3_col9,#T_479c1_row3_col11,#T_479c1_row3_col12,#T_479c1_row3_col15,#T_479c1_row3_col16,#T_479c1_row4_col17,#T_479c1_row5_col10,#T_479c1_row7_col14,#T_479c1_row8_col3,#T_479c1_row9_col13,#T_479c1_row10_col5,#T_479c1_row11_col2,#T_479c1_row11_col4{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_479c1_row3_col2{
#             background-color:  #24868e;
#             color:  #000000;
#         }#T_479c1_row3_col3,#T_479c1_row4_col6,#T_479c1_row12_col4{
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }#T_479c1_row3_col4{
#             background-color:  #77d153;
#             color:  #000000;
#         }#T_479c1_row3_col5{
#             background-color:  #471063;
#             color:  #f1f1f1;
#         }#T_479c1_row3_col7,#T_479c1_row6_col15{
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }#T_479c1_row3_col8,#T_479c1_row6_col1,#T_479c1_row9_col1,#T_479c1_row10_col1,#T_479c1_row11_col1,#T_479c1_row12_col1,#T_479c1_row13_col1,#T_479c1_row18_col1,#T_479c1_row19_col1,#T_479c1_row21_col1{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_479c1_row3_col10,#T_479c1_row6_col13{
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }#T_479c1_row3_col13{
#             background-color:  #25848e;
#             color:  #000000;
#         }#T_479c1_row3_col14{
#             background-color:  #287d8e;
#             color:  #000000;

# %% [markdown]
# ##### Самый высокий retention на 3-й месяц - у когорты 2017-06

# %% [markdown]
# #### Построй RFM-кластеры для пользователей. Выведи для каждого кластера средние значения метрик R, F, M (и опиши подробно, как были построены метрики R, F, M).

# %%
# собираю датафрейм, с которым буду работать
rfm_df = (customers[['customer_unique_id', 'customer_id']]
          .merge(orders[['customer_id', 'order_id', 'order_status', 'order_purchase_timestamp']])
          .merge(items[['order_id', 'product_id', 'price']]))

# %%
rfm_df.shape
# Out:
# (112650, 7)

# %%
rfm_df.head()
# Out:
#                  customer_unique_id                       customer_id  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  290c77bc529b7ac935b93aa66c333dc3  18955e83d337fd6b2def6b18a428ac77
# 2  060e732b5b29e8181a18229c7b0b2b5e  4e7b3e00288586ebd08712fdd0374a03
# 3  259dac757896d24d7702b9acbbff3f3c  b2b6027bc5c5109e529d4dc6358b12c3
# 4  345ecd01c38d18a9036ed96c73b8d066  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#                          product_id   price
# 0  a9516a079e37a9c9c36b9b78b10169e8  124.99
# 1  4aa6014eceb682077f9dc4bffebc05b0  289.00
# 2  bd07b66896d6f1494f5b86251848ced7  139.94
# 3  a5647c44af977b148e0a3a4751a09e2e  149.94
# 4  9391a573abe00141c56e38d84d7d5b3b  230.00

# %% [markdown]
# ###### R - recency — давность

# %%
# Добавляю колонку, которая будет учитывать давность покупки в днях относительно последнего заказа в датафрейме

rfm_df['recency'] = (rfm_df.order_purchase_timestamp.max() - rfm_df.order_purchase_timestamp).dt.days

# %%
(rfm_df.groupby(['customer_unique_id'])
            .agg({'recency' : 'min'})
            .sort_values('recency').describe())
# Out:
#             recency
# count  95420.000000
# mean     242.600377
# std      153.160320
# min        0.000000
# 25%      118.000000
# 50%      223.000000
# 75%      352.000000
# max      728.000000

# %% [markdown]
# В группе "recency" три категории. Мне кажется, есть смысл отсортировать пользователей, учитывая распределение давности покупок по квартилям:
#
#  - пользователи, совершвшие последнюю покупку более, чем 352 дня назад - давние пользователи - 1
#  - пользователи, совершвшие последнюю покупку 118-352 дня назад - относительно недавние, "спящие", пользователи (это около половины всех пользователей) - 2
#  - пользователи, совершвшие последнюю покупку 0-117 дней назад - недавние пользователи (их примерно 25%) - 3

# %%
rfm_df['recency_cut'] = pd.cut(rfm_df.recency, 
                               [0, 118, 353, 730], 
                               labels=['3', '2', '1'], 
                               right=False)

# %%
(rfm_df.order_purchase_timestamp.max() - rfm_df.order_purchase_timestamp).dt.days
# Out:
# 0         474
# 1         233
# 2         106
# 3         173
# 4          35
#          ...
# 112645    148
# 112646    152
# 112647    147
# 112648    303
# 112649    257
# Name: order_purchase_timestamp, Length: 112650, dtype: int64

# %%
rfm_df.head()
# Out:
#                  customer_unique_id                       customer_id  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  290c77bc529b7ac935b93aa66c333dc3  18955e83d337fd6b2def6b18a428ac77
# 2  060e732b5b29e8181a18229c7b0b2b5e  4e7b3e00288586ebd08712fdd0374a03
# 3  259dac757896d24d7702b9acbbff3f3c  b2b6027bc5c5109e529d4dc6358b12c3
# 4  345ecd01c38d18a9036ed96c73b8d066  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#                          product_id   price  recency recency_cut
# 0  a9516a079e37a9c9c36b9b78b10169e8  124.99      474           1
# 1  4aa6014eceb682077f9dc4bffebc05b0  289.00      233           2
# 2  bd07b66896d6f1494f5b86251848ced7  139.94      106           3
# 3  a5647c44af977b148e0a3a4751a09e2e  149.94      173           2
# 4  9391a573abe00141c56e38d84d7d5b3b  230.00       35           3

# %%
rfm_df.order_purchase_timestamp.dt.day
# Out:
# 0         16
# 1         12
# 2         19
# 3         13
# 4         29
#           ..
# 112645     7
# 112646     4
# 112647     8
# 112648     3
# 112649    19
# Name: order_purchase_timestamp, Length: 112650, dtype: int64

# %%
# Начиаю собрать итоговый датафрейм
# Записываю в него уникальных пользователей, последнюю активность и их максимальный ранг по шкале recency

rfm_result = (rfm_df.groupby(['customer_unique_id'], as_index=False)
                    .agg({'recency_cut' : 'max', 'recency' : 'min'}))

# %% [markdown]
# ##### F - frequency — частота

# %%
# смотрю описательную статистику по количеству выполненных заказов на клиента

rfm_df[rfm_df.order_status == 'delivered'].groupby(['customer_unique_id']).agg({'order_id' : 'nunique'}).describe()
# Out:
#            order_id
# count  93358.000000
# mean       1.033420
# std        0.209097
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       15.000000

# %%
# большинство клиентов совершает только один заказ, поэтому
# считаю, сколько клиентов сделали сколько заказов
(rfm_df[rfm_df.order_status == 'delivered'].groupby(['customer_unique_id'], as_index=False)
                                           .agg({'order_id' : 'nunique'})
                                           .groupby('order_id')
                                           .agg({'customer_unique_id' : 'count'})
)
# Out:
#           customer_unique_id
# order_id
# 1                      90557
# 2                       2573
# 3                        181
# 4                         28
# 5                          9
# 6                          5
# 7                          3
# 9                          1
# 15                         1

# %%
(rfm_df[rfm_df.order_status != 'delivered'].groupby(['customer_unique_id'], as_index=False)
                                           .agg({'order_id' : 'nunique'})
                                           .groupby('order_id')
                                           .agg({'customer_unique_id' : 'count'})
)
# Out:
#           customer_unique_id
# order_id
# 1                       2172
# 2                          8

# %% [markdown]
# Группу "frequency" (частота покупок) я разобью на категории следующим образом:
#
# - у клиента одна покупка или нет выполненных заказов - 1
# - у клиента две покупки - 3
# - клиент совершил 3 и более покупки - 3

# %%
temp = (
            rfm_df[rfm_df.order_status == 'delivered']
                    .groupby(['customer_unique_id'], as_index=False)
                    .agg({'order_id' : 'nunique'})
        )
temp['frequency'] = temp['order_id']
temp['frequency_cut'] = pd.cut(temp.order_id, [0, 1, 2, 100], labels=['1', '2', '3'])

# %%
temp.head()
# Out:
#                  customer_unique_id  order_id  frequency frequency_cut
# 0  0000366f3b9a7992bf8c76cfdf3221e2         1          1             1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f         1          1             1
# 2  0000f46a3911fa3c0805444483337064         1          1             1
# 3  0000f6ccb0745a6a4b88665a16c9f078         1          1             1
# 4  0004aac84e0df4da2b147fca70cf8255         1          1             1

# %%
# Добавляю frequency к результирующему датафрейму
rfm_result = rfm_result.merge(temp[['customer_unique_id', 'frequency', 'frequency_cut']], how='left')

# %%
# В датафрейме появились пустые ячейки - это frequency клиентов, у которых нет успешно завершенных заказов. Я заполню их единицами (для рангов) и нолями
rfm_result.frequency_cut.fillna('1', inplace=True)
rfm_result.frequency.fillna(0, inplace=True)

# %%
rfm_result.isna().sum()
# Out:
# customer_unique_id    0
# recency_cut           0
# recency               0
# frequency             0
# frequency_cut         0
# dtype: int64

# %%
rfm_result.head()
# Out:
#                  customer_unique_id recency_cut  recency  frequency  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2           3      115        1.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f           2      118        1.0
# 2  0000f46a3911fa3c0805444483337064           1      541        1.0
# 3  0000f6ccb0745a6a4b88665a16c9f078           2      325        1.0
# 4  0004aac84e0df4da2b147fca70cf8255           2      292        1.0
#
#   frequency_cut
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# ##### M - monetary — деньги

# %%
rfm_df.head()
# Out:
#                  customer_unique_id                       customer_id  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  290c77bc529b7ac935b93aa66c333dc3  18955e83d337fd6b2def6b18a428ac77
# 2  060e732b5b29e8181a18229c7b0b2b5e  4e7b3e00288586ebd08712fdd0374a03
# 3  259dac757896d24d7702b9acbbff3f3c  b2b6027bc5c5109e529d4dc6358b12c3
# 4  345ecd01c38d18a9036ed96c73b8d066  4f2d8ab171c80ec8364f7c12e35b23ad
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#                          product_id   price  recency recency_cut
# 0  a9516a079e37a9c9c36b9b78b10169e8  124.99      474           1
# 1  4aa6014eceb682077f9dc4bffebc05b0  289.00      233           2
# 2  bd07b66896d6f1494f5b86251848ced7  139.94      106           3
# 3  a5647c44af977b148e0a3a4751a09e2e  149.94      173           2
# 4  9391a573abe00141c56e38d84d7d5b3b  230.00       35           3

# %%
# смотрю описательную статистику по сумме покупок на клиента

(
    rfm_df[rfm_df.order_status == 'delivered']
     .groupby(['customer_unique_id'])
     .agg({'price' : 'sum'})
     .describe()
)
# Out:
#               price
# count  93358.000000
# mean     141.621480
# std      215.694014
# min        0.850000
# 25%       47.650000
# 50%       89.730000
# 75%      154.737500
# max    13440.000000

# %% [markdown]
# Группу "monetary", как и "recency", я разделю, отталкиваясь от распределения сумм по квартилям:
#
# - клиенты, которые потратили до 47 ед. денег и клиенты, чьи заказы не были успешно доставлены - 1
# - клиенты, потратившие от 47 до 154 ед. денег - 2
# - клиенты, потратившие больше 154 ед.денег - 3

# %%
temp = (
        rfm_df[rfm_df.order_status == 'delivered']
             .groupby(['customer_unique_id'], as_index=False)
             .agg({'price' : 'sum'})
        )
temp['monetary'] = temp.price
temp['monetary_сut'] = pd.cut(temp.price, [0, 47, 154, 100000], labels=['1', '2', '3'])

# %%
temp.head()
# Out:
#                  customer_unique_id   price  monetary monetary_сut
# 0  0000366f3b9a7992bf8c76cfdf3221e2  129.90    129.90            2
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f   18.90     18.90            1
# 2  0000f46a3911fa3c0805444483337064   69.00     69.00            2
# 3  0000f6ccb0745a6a4b88665a16c9f078   25.99     25.99            1
# 4  0004aac84e0df4da2b147fca70cf8255  180.00    180.00            3

# %%
# Добавляю frequency к результирующему датафрейму и заполняю пустые значения единицами и нолями, как в случае с frequency

rfm_result = rfm_result.merge(temp[['customer_unique_id', 'monetary', 'monetary_сut']], how='left')
rfm_result.monetary_сut.fillna('1', inplace=True)
rfm_result.monetary.fillna(0, inplace=True)
rfm_result.head()
# Out:
#                  customer_unique_id recency_cut  recency  frequency  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2           3      115        1.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f           2      118        1.0
# 2  0000f46a3911fa3c0805444483337064           1      541        1.0
# 3  0000f6ccb0745a6a4b88665a16c9f078           2      325        1.0
# 4  0004aac84e0df4da2b147fca70cf8255           2      292        1.0
#
#   frequency_cut  monetary monetary_сut
# 0             1    129.90            2
# 1             1     18.90            1
# 2             1     69.00            2
# 3             1     25.99            1
# 4             1    180.00            3

# %%
rfm_result.shape
# Out:
# (95420, 7)

# %%
rfm_result['RFM_cluster'] = rfm_result.recency_cut.astype(str) + rfm_result.frequency_cut.astype(str) + rfm_result.monetary_сut.astype(str)

# %% [markdown]
# ##### Вывод среднего для каждого кластера

# %%
rfm_result.groupby('RFM_cluster', as_index=False)[['recency', 'frequency', 'monetary']].mean()
# Out:
#    RFM_cluster     recency  frequency    monetary
# 0          111  462.218741   0.889949   25.701659
# 1          112  454.205413   1.000000   89.157182
# 2          113  458.214141   1.000000  360.508744
# 3          121  403.813953   2.000000   36.031163
# 4          122  333.178392   2.000000  103.451658
# 5          123  318.275214   2.000000  344.625795
# 6          131  585.750000   3.250000   32.675000
# 7          132  291.068966   3.137931  112.074483
# 8          133  241.144330   3.494845  518.868144
# 9          211  225.156210   0.919608   26.605612
# 10         212  225.589012   1.000000   91.681847
# 11         213  225.947185   1.000000  344.668411
# 12         221  150.238095   2.000000   34.813095
# 13         222  186.084536   2.000000  102.253918
# 14         223  175.807040   2.000000  350.539048
# 15         232  156.916667   3.000000  110.037500
# 16         233  131.934211   3.486842  471.100658
# 17         311   59.651852   0.945185   27.460441
# 18         312   60.438196   1.000000   92.072919
# 19         313   61.589165   1.000000  362.298631
# 20         321   54.818182   2.000000   34.730909
# 21         322   50.934783   2.000000   99.681848
# 22         323   49.433333   2.000000  383.161267
# 23         332   37.500000   3.000000   89.330000
# 24         333   59.833333   3.166667  990.226667
